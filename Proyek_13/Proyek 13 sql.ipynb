#          Pada project kali ini saya akan melakukan analisa tentang rekomendasi buku yang nantinya bisa digunakan sistem untuk memberi rekomendasi pada pengguna aplikasi bacaan buku elektronik ini, rekomendasi bacaan menggunakan data tentang buku, penerbit, penulis, serta rating dan ulasan pelanggan atas buku terkait pada kasus kali ini, sehingga hasil rekomendasi buku nanti yang diberikan tidak mengecewakan pembaca seminimal mungkin bisa membuat pembaca terbantu ingin membaca buku apa di aplikasi ini. Tahapan analisis ini pertama adalah membatasi tahun terbit buku agar datanya tidak terlalu banyak dan tujuannya memberikan update bagi para pembaca untuk membaca buku keluaran tahun tertentu. Melihat rating buku yang diterbitkan di tahun tersebut, mengidentifikasi penerbit yang mengeluarkan buku dengan rating tertentu, biasanya rating semakin tinggi maka bacaan semakin bagus karena menjadi favorit dari sebagian besar kalangan dan berpengaruh juga pada penerbit, mengidentifikasi penulis buku yang rating bukunya dianggap bagus , lalu melihat orang yang me-review buku tersebut karena biasanya orang yang melakukan review adalah orang yang ahli dibidangnya dan semakin banyak buku yang dia review maka semakin tinggi penilaian reviewer tersebut pada suatu buku sehingga bisa dikatakan jika reviewer mengatakan buku yang dia review bagus maka rekomen untuk dibaca

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
db_config = {'user': 'practicum_student',         # nama pengguna
             'pwd': 's65BlTKV3faNIGhmvJVzOqhs', # kata sandi
             'host': 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net',
             'port': 6432,              # port koneksi
             'db': 'data-analyst-final-project-db'}          # nama database

connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(db_config['user'],
                                                                     db_config['pwd'],
                                                                       db_config['host'],
                                                                       db_config['port'],
                                                                       db_config['db'])

engine = create_engine(connection_string, connect_args={'sslmode':'require'})

# %%
query=("select *from books")
data_books=pd.io.sql.read_sql(query, con=engine)
data_books
# Out:
#      book_id  author_id                                              title  \
# 0          1        546                                       'Salem's Lot
# 1          2        465                 1 000 Places to See Before You Die
# 2          3        407  13 Little Blue Envelopes (Little Blue Envelope...
# 3          4         82  1491: New Revelations of the Americas Before C...
# 4          5        125                                               1776
# ..       ...        ...                                                ...
# 995      996        571           Wyrd Sisters (Discworld  #6; Witches #2)
# 996      997        454                        Xenocide (Ender's Saga  #3)
# 997      998        201                                    Year of Wonders
# 998      999         94                        You Suck (A Love Story  #2)
# 999     1000        509  Zen and the Art of Motorcycle Maintenance: An ...
#
#      num_pages publication_date  publisher_id
# ...

# %%
query="SELECT * FROM authors"
data_authors = pd.io.sql.read_sql(query, con=engine)
data_authors
# Out:
#      author_id                                author
# 0            1                            A.S. Byatt
# 1            2        Aesop/Laura Harris/Laura Gibbs
# 2            3                       Agatha Christie
# 3            4                         Alan Brennert
# 4            5              Alan Moore/David   Lloyd
# ..         ...                                   ...
# 631        632         William Strunk Jr./E.B. White
# 632        633                           Zadie Smith
# 633        634                 Zilpha Keatley Snyder
# 634        635                    Zora Neale Hurston
# 635        636  Åsne Seierstad/Ingrid Christopherson
#
# [636 rows x 2 columns]

# %%
query="SELECT * FROM ratings"
data_ratings = pd.io.sql.read_sql(query,con=engine)
data_ratings
# Out:
#       rating_id  book_id        username  rating
# 0             1        1      ryanfranco       4
# 1             2        1   grantpatricia       2
# 2             3        1    brandtandrea       5
# 3             4        2        lorichen       3
# 4             5        2     mariokeller       2
# ...         ...      ...             ...     ...
# 6451       6452     1000  carolrodriguez       4
# 6452       6453     1000         wendy18       4
# 6453       6454     1000      jarvispaul       5
# 6454       6455     1000           zross       2
# 6455       6456     1000         fharris       5
#
# [6456 rows x 4 columns]

# %%
query="SELECT * FROM publishers"
data_publisher = pd.io.sql.read_sql(query,con=engine)
data_publisher
# Out:
#      publisher_id                          publisher
# 0               1                                Ace
# 1               2                           Ace Book
# 2               3                          Ace Books
# 3               4                      Ace Hardcover
# 4               5  Addison Wesley Publishing Company
# ..            ...                                ...
# 335           336         Workman Publishing Company
# 336           337                         Wyatt Book
# 337           338              Yale University Press
# 338           339                           Yearling
# 339           340                     Yearling Books
#
# [340 rows x 2 columns]

# %%
query ="SELECT *FROM reviews"
data_reviews = pd.io.sql.read_sql(query,con=engine)
data_reviews
# Out:
#       review_id  book_id        username  \
# 0             1        1    brandtandrea
# 1             2        1      ryanfranco
# 2             3        2        lorichen
# 3             4        3   johnsonamanda
# 4             5        3     scotttamara
# ...         ...      ...             ...
# 2788       2789      999      martinadam
# 2789       2790     1000         wknight
# 2790       2791     1000  carolrodriguez
# 2791       2792     1000         wendy18
# 2792       2793     1000      jarvispaul
#
#                                                    text
# 0     Mention society tell send professor analysis. ...
# 1     Foot glass pretty audience hit themselves. Amo...
# 2     Listen treat keep worry. Miss husband tax but ...
# 3     Finally month interesting blue could nature cu...
# 4     Nation purpose heavy give wait song will. List...
# ...                                                 ...
# 2788  Later hospital turn easy community. Fact same ...
# ...

# %%
#Hitung jumlah buku yang dirilis setelah tanggal 1 Januari 2000.
query= "SELECT COUNT(*) total_book FROM books WHERE publication_date >'2000-01-01'"
total_book = pd.io.sql.read_sql(query,con=engine)
total_book
# Out:
#    total_book
# 0         819

# %%
#Hitung jumlah ulasan pengguna dan rating rata-rata untuk setiap buku
query="SELECT book_id, COUNT(username)as total_pengulas ,AVG(rating)as Average_Rating FROM ratings GROUP BY book_id ORDER BY book_id ASC "
summary = pd.io.sql.read_sql(query, con=engine)
summary
# Out:
#      book_id  total_pengulas  average_rating
# 0          1               3        3.666667
# 1          2               2        2.500000
# 2          3               3        4.666667
# 3          4               2        4.500000
# 4          5               6        4.000000
# ..       ...             ...             ...
# 995      996               3        3.666667
# 996      997               5        3.400000
# 997      998               5        3.200000
# 998      999               2        4.500000
# 999     1000               6        3.833333
#
# [1000 rows x 3 columns]

# %% [markdown]
#  Identifikasi penerbit yang telah menerbitkan jumlah buku terbanyak, dengan jumlah halaman lebih dari 50 (hal ini akan membantu Anda dalam mengecualikan brosur dan publikasi serupa dari analisis Anda).

# %%
query="SELECT p.publisher, COUNT(*) AS Jumlah FROM books b INNER JOIN publishers p ON p.publisher_id = b.publisher_id WHERE b.num_pages > 50 GROUP BY p.publisher ORDER BY Jumlah DESC"

publisher_book = pd.io.sql.read_sql(query, con=engine)
publisher_book
# Out:
#                                              publisher  jumlah
# 0                                        Penguin Books      42
# 1                                              Vintage      31
# 2                             Grand Central Publishing      25
# 3                                     Penguin Classics      24
# 4                                     Ballantine Books      19
# ..                                                 ...     ...
# 329                                         Turtleback       1
# 330  Atheneum Books for Young Readers: Richard Jack...       1
# 331                                     Penguin Signet       1
# 332                                    Victor Gollancz       1
# 333                      Harvard Business Review Press       1
#
# [334 rows x 2 columns]

# %% [markdown]
# Identifikasi penulis dengan rating rata-rata buku tertinggi: temukan buku dengan rating minimal 50

# %%
query="SELECT a.author,b.title, COUNT(r.rating)FROM books b INNER JOIN authors a ON b.author_id = a.author_id INNER JOIN ratings r ON b.book_id = r.book_id GROUP BY a.author,b.title HAVING COUNT(r.rating )>50 "

book_rating = pd.io.sql.read_sql(query, con=engine)
book_rating
# Out:
#                                                author  \
# 0                                           Dan Brown
# 1                   Markus Zusak/Cao Xuân Việt Khương
# 2                                       Arthur Golden
# 3                                          Lois Lowry
# 4                                      J.R.R. Tolkien
# 5                                      J.R.R. Tolkien
# 6                          J.K. Rowling/Mary GrandPré
# 7                          J.K. Rowling/Mary GrandPré
# 8                                           Dan Brown
# 9                                        Rick Riordan
# 10  William Shakespeare/Paul Werstine/Barbara A. M...
# 11                                    Stephenie Meyer
# 12                         J.K. Rowling/Mary GrandPré
# 13           Paulo Coelho/Alan R. Clarke/Özdemir İnce
# 14                                     John Steinbeck
# 15                                  Louisa May Alcott
# ...

# %% [markdown]
# Hitung jumlah rata-rata teks ulasan di antara pengguna yang memberi rating terhadap lebih dari 50 buku

# %%
query = " SELECT re.username, AVG(LENGTH(text)) AS panjang_ulasan FROM books b INNER JOIN reviews re ON b.book_id = re.book_id INNER JOIN ratings r ON b.book_id = r.book_id WHERE LENGTH(text) >50 IS NOT NULL GROUP BY re.username UNION ALL SELECT 'TOTAL AVG ',AVG(LENGTH(text)) from reviews WHERE LENGTH(text)>50 "
long = pd.io.sql.read_sql(query,con=engine)
long
# Out:
#            username  panjang_ulasan
# 0         zjohnston       62.110553
# 1           jnelson       77.473510
# 2      lewisdesiree       71.511628
# 3     patrickhudson      107.836879
# 4             ulowe      101.700000
# ..              ...             ...
# 156         dmiller       83.423077
# 157  charlesraymond       81.076923
# 158     isaiahreyes       85.250000
# 159       masonsara       87.063291
# 160      TOTAL AVG        98.168071
#
# [161 rows x 2 columns]
